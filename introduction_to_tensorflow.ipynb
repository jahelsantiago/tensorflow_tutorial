# %% [markdown]
# <a href="https://colab.research.google.com/github/jahelsantiago/tensorflow_tutorial/blob/master/introduction_to_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras as k
import matplotlib.pyplot as plt

# %% [markdown]
# ## RED QUE CALCULA  f(x) = 2X-1

# %% [markdown]
# ### Definir y compilar la red neuronal
# #### Crearemos un modelo con una neurona

# %%
model = k.Sequential([k.layers.Dense(units =1, input_shape=[1])])
# Out:
# WARNING:tensorflow:From C:\Users\ProBook\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# #### compilamos el modelo

# %%
model.compile(optimizer = "sgd", loss ="mean_squared_error")

# %% [markdown]
# #### damos los datos al modelo

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# #### Entrenamos la red neuronal

# %%
model.fit(xs,ys, epochs=500)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 173ms/sample - loss: 18.2618
# Epoch 2/500
# 6/6 [==============================] - 0s 998us/sample - loss: 14.6250
# Epoch 3/500
# 6/6 [==============================] - 0s 1000us/sample - loss: 11.7585
# Epoch 4/500
# 6/6 [==============================] - 0s 500us/sample - loss: 9.4980
# Epoch 5/500
# 6/6 [==============================] - 0s 501us/sample - loss: 7.7146
# Epoch 6/500
# 6/6 [==============================] - 0s 500us/sample - loss: 6.3064
# Epoch 7/500
# 6/6 [==============================] - 0s 333us/sample - loss: 5.1937
# Epoch 8/500
# 6/6 [==============================] - 0s 500us/sample - loss: 4.3135
# Epoch 9/500
# 6/6 [==============================] - 0s 333us/sample - loss: 3.6164
# Epoch 10/500
# 6/6 [==============================] - 0s 333us/sample - loss: 3.0633
# Epoch 11/500
# 6/6 [==============================] - 0s 500us/sample - loss: 2.6237
# Epoch 12/500
# 6/6 [==============================] - 0s 333us/sample - loss: 2.2734
# Epoch 13/500
# 6/6 [==============================] - 0s 167us/sample - loss: 1.9936
# Epoch 14/500
# 6/6 [==============================] - 0s 167us/sample - loss: 1.7692
# Epoch 15/500
# 6/6 [==============================] - 0s 333us/sample - loss: 1.5885
# Epoch 16/500
# 6/6 [==============================] - 0s 167us/sample - loss: 1.4424
# Epoch 17/500
# 6/6 [==============================] - 0s 333us/sample - loss: 1.3234
# Epoch 18/500
# 6/6 [==============================] - 0s 333us/sample - loss: 1.2259
# Epoch 19/500
# 6/6 [==============================] - 0s 500us/sample - loss: 1.1455
# Epoch 20/500
# 6/6 [==============================] - 0s 333us/sample - loss: 1.0784
# Epoch 21/500
# 6/6 [==============================] - 0s 333us/sample - loss: 1.0221
# Epoch 22/500
# 6/6 [==============================] - 0s 500us/sample - loss: 0.9741
# Epoch 23/500
# 6/6 [==============================] - 0s 333us/sample - loss: 0.9329
# Epoch 24/500
# 6/6 [==============================] - 0s 166us/sample - loss: 0.8971
# Epoch 25/500
# 6/6 [==============================] - 0s 500us/sample - loss: 0.8656
# Epoch 26/500
# 6/6 [==============================] - 0s 500us/sample - loss: 0.8375
# Epoch 27/500
# 6/6 [==============================] - 0s 166us/sample - loss: 0.8122
# Epoch 28/500
# 6/6 [==============================] - 0s 333us/sample - loss: 0.7891
# Epoch 29/500
# 6/6 [==============================] - 0s 333us/sample - loss: 0.7679
# Epoch 30/500
# 6/6 [==============================] - 0s 500us/sample - loss: 0.7481
# Epoch 31/500
# 6/6 [==============================] - 0s 167us/sample - loss: 0.7296
# Epoch 32/500
# 6/6 [==============================] - 0s 333us/sample - loss: 0.7122
# Epoch 33/500
# 6/6 [==============================] - 0s 333us/sample - loss: 0.6957
# Epoch 34/500
# 6/6 [==============================] - 0s 499us/sample - loss: 0.6799
# Epoch 35/500
# 6/6 [==============================] - 0s 167us/sample - loss: 0.6647
# Epoch 36/500
# 6/6 [==============================] - 0s 500us/sample - loss: 0.6501
# Epoch 37/500
# 6/6 [==============================] - 0s 166us/sample - loss: 0.6360
# Epoch 38/500
# 6/6 [==============================] - 0s 500us/sample - loss: 0.6224
# Epoch 39/500
# 6/6 [==============================] - 0s 500us/sample - loss: 0
# **Normalizamos**

# %%
train_x = train_x/255
test_x = test_x/255

# %% [markdown]
# ### Creamos el modelo

# %%
model = k.Sequential([k.layers.Flatten(input_shape=(28,28)),
                      k.layers.Dense(128, activation= tf.nn.relu),
                      k.layers.Dense(10,activation=tf.nn.softmax)
])

# %%
i = 1000
plt.imshow(train_x[i])
print(train_y[i])
# Out:
# 1

# %%
model.compile(optimizer="adam", loss= "sparse_categorical_crossentropy")
model.fit(train_x, train_y, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.7537
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6572
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5727
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5324
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5179

# %% [markdown]
# mide lo bien o mal que lo hace con en test set, basado en los labels

# %%
model.evaluate(test_x,test_y)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.5414
# 0.5413801074028015

# %% [markdown]
# hace predicciones basadas en el modelo ya creado, retorna la probabilidad de que sea cada uno de esos

# %%
clasification = model.predict(test_x)
print(clasification[1])
# Out:
# [1.6674527e-05 5.8931038e-10 9.9866140e-01 1.8042867e-08 1.1760667e-03
#  1.2381649e-11 1.4578711e-04 6.4471542e-16 3.4664149e-09 1.6513146e-14]

# %% [markdown]
# **Detener los epoch cuando se llegue a cierto valor x**
#
# cuando se alcance el valor deseado detener el training, se hace mediante callbacks

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
    if(logs["loss"] < 0.4):
      print("\n accuary del 60% cosneguida")
      self.model.stop_training = True #detiene el training

callbacks = myCallback()
mnist = tf.keras.datasets.fashion_mnist
(train_x, train_y), (test_x, test_y) = mnist.load_data() #cargar los datos
train_x = train_x/255 ; test_y = test_y / 255 #normalizar

model = tf.keras.Sequential([ #creamos el modelo
                             tf.keras.layers.Flatten(),
                             tf.keras.layers.Dense(512, activation= "relu"),
                             tf.keras.layers.Dense(10,activation="softmax")
])
model.compile(optimizer="adam", loss = "sparse_categorical_crossentropy")
model.fit(train_x,train_y, epochs=10, callbacks = [callbacks])
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4751
# Epoch 2/10
# 1863/1875 [============================>.] - ETA: 0s - loss: 0.3612accuary del 60% cosneguida
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3608

# %% [markdown]
# ## Hand writer digit recognizer

# %% [markdown]
# steps:
# 1. load the data set
# 2. divide in train an test
# 3. normalize de images
# 4. create the model, with layers and activations
# 5. compile de modelo with optimization and loss function
# 6. fit the model with epochs and call back
# 7. evaluate the model with test set
# 8. predict

# %%
def train_mnist():
    class myCallback(tf.keras.callbacks.Callback):    
        def on_epoch_end(self, epoch, logs = {}):
            if(logs.get("accuracy") >= 0.99):
              print("\nReached 99% accuracy so cancelling training!")
              self.model.stop_training = True #detiene el training    

    mnist = tf.keras.datasets.mnist
    (x_train, y_train),(x_test, y_test) = mnist.load_data()

    x_train = x_train/255    
    
    callbacks = myCallback()            

    model = tf.keras.models.Sequential([                
        k.layers.Flatten(),
        k.layers.Dense(512, activation= "relu"),      
        k.layers.Dense(10, activation= "softmax")        
    ])

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    # model fitting
    history = model.fit(x_train,y_train,epochs = 10, callbacks = [callbacks])
    # model fitting
    return history.epoch, history.history['accuracy'][-1]

# %%
train_mnist()
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2012 - accuracy: 0.9411
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0819 - accuracy: 0.9743
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0525 - accuracy: 0.9831
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0371 - accuracy: 0.9881
# Epoch 5/10
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.0267 - accuracy: 0.9913
# Reached 99% accuracy so cancelling training!
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0267 - accuracy: 0.9913
# ([0, 1, 2, 3, 4], 0.991266667842865)

# %% [markdown]
# ## Fashion mist conv

# %%
mnist = k.datasets.fashion_mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000,28,28,1) #cambiar la forma
x_train = x_train/255 ; x_test = x_test / 255 #normalizamos

x_test = x_test.reshape(10000,28,28,1)
x_test = x_test/255

# %%
print(x_train[0].shape)
# Out:
# (28, 28, 1)

# %%
model = k.models.Sequential([
        k.layers.Conv2D(64, (3,3),input_shape = (28,28,1)),
        k.layers.MaxPool2D(),
        k.layers.Conv2D(64,(3,3)),
        k.layers.MaxPool2D(),
        k.layers.Flatten(),
        k.layers.Dense(128, activation= "relu"),      
        k.layers.Dense(10, activation= "softmax")
])
model.compile(optimizer= "adam", loss= "SparseCategoricalCrossentropy")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               204928
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4268
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2894
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2386
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2019
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1714
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1439
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1234
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1060
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0937
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0807

# %% [markdown]
# evaluamos el rendimiento

# %%
test_loss = model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 4s 14ms/step - loss: 3.0911

# %% [markdown]
# #### visualizacion de las activaciones

# %% [markdown]
# - model.layers: lista de layers
# - model.laye[i].output: tensor of neurons
# - model.laye[i].output.predict( ... ): activations of neurons
# - model.laye[i].output.predict( ... )[x]: activation of neuron x

# %%
layers = model.layers
layers
# Out:
# [<tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f9ad9aa3be0>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f9ad9a34668>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f9ad9aadac8>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f9ad9a346a0>,
#  <tensorflow.python.keras.layers.core.Flatten at 0x7f9ad9a34630>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f9ad9a34b38>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f9ad9a3ef28>]

# %%
layers[0].output
# Out:
# <tf.Tensor 'conv2d_16/BiasAdd:0' shape=(None, 26, 26, 64) dtype=float32>

# %%
print(test_y[:100])
# Out:
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4 9 6 6 5 4 0 7 4 0 1 3 1 3 4 7 2 7
#  1 2 1 1 7 4 2 3 5 1 2 4 4 6 3 5 5 6 0 4 1 9 5 7 8 9 3 7 4 6 4 3 0 7 0 2 9
#  1 7 3 2 9 7 7 6 2 7 8 4 7 3 6 1 3 6 9 3 1 4 1 7 6 9]

# %%
f, axarr = plt.subplots(3,4)
FIRST_IMAGE=2
SECOND_IMAGE=5
THIRD_IMAGE=-4
CONVOLUTION_NUMBER = 3

layer_outputs = [layer.output for layer in model.layers] #lista de
activation_model = tf.keras.models.Model(inputs = model.input, outputs = layer_outputs)#creamos modelos pequeños con de 1 layer con solo las activaciones

for x in range(0,4):
  f1 = activation_model.predict(x_test[FIRST_IMAGE].reshape(1, 28, 28, 1))[x]
  axarr[0,x].imshow(f1[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[0,x].grid(False)
  f2 = activation_model.predict(x_test[SECOND_IMAGE].reshape(1, 28, 28, 1))[x]
  axarr[1,x].imshow(f2[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[1,x].grid(False)
  f3 = activation_model.predict(x_test[THIRD_IMAGE].reshape(1, 28, 28, 1))[x]
  axarr[2,x].imshow(f3[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[2,x].grid(False)

# %% [markdown]
# ## Horses and humans

# %% [markdown]
# añadir las imagenes en los directorios
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Traemos los datos de internet, estos seran almacenados en la carpeta tmp

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip \
    -O /tmp/horse-or-human.zip
# Out:
# --2020-08-07 17:23:59--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.204.128, 172.217.203.128, 173.194.217.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.204.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘/tmp/horse-or-human.zip’
#
# /tmp/horse-or-human 100%[===================>] 142.65M   189MB/s    in 0.8s
#
# 2020-08-07 17:24:00 (189 MB/s) - ‘/tmp/horse-or-human.zip’ saved [149574867/149574867]

# %% [markdown]
# leemos y extraemos el archivo zip de los caballos y humanos

# %%
import os
import zipfile
#extraer zip con python
path_zip = "/tmp/horse-or-human.zip" #define la ruto de la localizacion del zip
zip_ref = zipfile.ZipFile(path_zip, "r") #lee el archivo zip usando la ruta
zip_ref.extractall("/tmp/horse-or-human") #extrae el zip y lo deja en la carpeta con el nombre indicado
zip_ref.close()

# %% [markdown]
# especificamos la ruta de los train y test

# %%
train_horse_path = os.path.join("/tmp/horse-or-human/horses") #directorio con las imagenes de horses
train_human_path = os.path.join("/tmp/horse-or-human/humans") #directorio con las imagenes de humans

# %% [markdown]
# vemos el nombre de las imagenes

# %%
horse_names = os.listdir("/tmp/horse-or-human/horses")#retorna una lista con el nombre de los archivos en ese dir
print("Horse files",horse_names[:10])
human_names = os.listdir(train_human_path)
print("humans files",human_names[:10])
# Out:
# Horse files ['horse16-7.png', 'horse01-6.png', 'horse41-1.png', 'horse07-4.png', 'horse02-1.png', 'horse49-7.png', 'horse02-7.png', 'horse49-0.png', 'horse31-3.png', 'horse06-6.png']
# humans files ['human08-04.png', 'human03-00.png', 'human04-26.png', 'human11-04.png', 'human13-10.png', 'human03-22.png', 'human14-19.png', 'human03-27.png', 'human02-05.png', 'human10-02.png']

# %% [markdown]
# vemos el numero total de imagenes en los directorios

# %%
print("total horses ", len(horse_names))
print("total humans ", len(human_names))
# Out:
# total horses  500
# total humans  527

# %% [markdown]
# vemos unas cuantas figuaras

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_horse_pix = [os.path.join(train_horse_path, fname) 
                for fname in horse_names[pic_index-8:pic_index]]
next_human_pix = [os.path.join(train_human_path, fname) 
                for fname in human_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_horse_pix+next_human_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# construmos nuestro modelo

# %%
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 300x300 with 3 bytes color
    # This is the first convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fifth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('horses') and 1 for the other ('humans')
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 298, 298, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 149, 149, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 147, 147, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 71, 71, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 33, 33, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1606144
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,704,097
# Trainable params: 1,704,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])

# %%
train_gen = ImageDataGenerator(rescale=1/255) #creamos una instancia del objeto y normalizamos
train_data = train_gen.flow_from_directory(
    "/tmp/horse-or-human", #colocarlo en el directoy "Training" de la imagen de arriba
    target_size = (300,300), #cambia las imagenes de tamaño de forma automatica
    batch_size = 128, #tamño del batch
    class_mode = "binary" #elige el tipo de clases creadas
)
# Out:
# Found 1027 images belonging to 2 classes.

# %%
history = model.fit(
      train_data,
      steps_per_epoch=8,  
      epochs=15,
      verbose=1)
# Out:
# Epoch 1/15
# 8/8 [==============================] - 8s 976ms/step - loss: 0.6166 - accuracy: 0.7397
# Epoch 2/15
# 8/8 [==============================] - 6s 733ms/step - loss: 0.4017 - accuracy: 0.8298
# Epoch 3/15
# 8/8 [==============================] - 7s 831ms/step - loss: 0.1897 - accuracy: 0.9333
# Epoch 4/15
# 8/8 [==============================] - 6s 737ms/step - loss: 0.0874 - accuracy: 0.9711
# Epoch 5/15
# 8/8 [==============================] - 6s 737ms/step - loss: 0.0669 - accuracy: 0.9755
# Epoch 6/15
# 8/8 [==============================] - 6s 742ms/step - loss: 0.2232 - accuracy: 0.9199
# Epoch 7/15
# 8/8 [==============================] - 6s 745ms/step - loss: 0.2026 - accuracy: 0.9255
# Epoch 8/15
# 8/8 [==============================] - 6s 742ms/step - loss: 0.1222 - accuracy: 0.9511
# Epoch 9/15
# 8/8 [==============================] - 7s 826ms/step - loss: 0.0962 - accuracy: 0.9658
# Epoch 10/15
# 8/8 [==============================] - 6s 746ms/step - loss: 0.0699 - accuracy: 0.9755
# Epoch 11/15
# 8/8 [==============================] - 6s 744ms/step - loss: 0.0397 - accuracy: 0.9855
# Epoch 12/15
# 8/8 [==============================] - 6s 749ms/step - loss: 0.0924 - accuracy: 0.9566
# Epoch 13/15
# 8/8 [==============================] - 6s 715ms/step - loss: 0.0835 - accuracy: 0.9622
# Epoch 14/15
# 8/8 [==============================] - 6s 747ms/step - loss: 0.0769 - accuracy: 0.9733
# Epoch 15/15
# 8/8 [==============================] - 7s 837ms/step - loss: 0.0722 - accuracy: 0.9677

# %% [markdown]
# evaluamos los resultados con imagenes reales

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image 

uploaded = files.upload() #opcion para cargar la imagen

for fn in uploaded.keys():
  path = "/content/" + fn 
  img = image.load_img(path, target_size = (300,300)) #cargamos la imagen en el path y la adecuamos a 300x300
  x = image.img_to_array(img) #convertimos la imagen en un arreglo de numpy
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0] > 0.5:
    print(fn + "es humano")
  else:
    print(fn + " es un hermoso caballo")
# Out:
#      <input type="file" id="files-02e56875-0908-46bc-8782-ad84c2a455fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02e56875-0908-46bc-8782-ad84c2a455fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving caballos-1024x538.jpg to caballos-1024x538 (2).jpg
# [5.195872e-09]
# caballos-1024x538.jpg es un hermoso caballo

# %%
import numpy as np
import random
from tensorflow.keras.preprocessing.image import img_to_array, load_img

successive_outputs = [layer.output for layer in model.layers[1:]]# sacamos las layers del modelo

visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs) #creamos un nuevo modelo que toma de input una imagen y genera las inouts intermedias

horse_img_files = [os.path.join(train_horse_path, f) for f in horse_names] #seleccionamos todas las imagenes
human_img_files = [os.path.join(train_human_path, f) for f in human_names]
img_path = random.choice(horse_img_files + human_img_files) #elegimos una path de imagen aleatoria

img = load_img(img_path, target_size=(300, 300))  # cargamos la imagen 
x = img_to_array(img)  # lo convertimos a un array
x = x.reshape((1,) + x.shape)  # equal to x.reshape(1, 300, 300, 3)

# Rescale by 1/255
x /= 255

# Let's run our image through our network, thus obtaining all
# intermediate representations for this image.
successive_feature_maps = visualization_model.predict(x)

# These are the names of the layers, so can have them as part of our plot
layer_names = [layer.name for layer in model.layers[1:]]

# Now let's display our representations
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  if len(feature_map.shape) == 4:
    # Just do this for the conv / maxpool layers, not the fully-connected layers
    n_features = feature_map.shape[-1]  # number of features in feature map
    # The feature map has shape (1, size, size, n_features)
    size = feature_map.shape[1]
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    for i in range(n_features):
      # Postprocess the feature to make it visually palatable
      x = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std()
      x *= 64
      x += 128
      x = np.clip(x, 0, 255).astype('uint8')
      # We'll tile each filter into this big horizontal grid
      display_grid[:, i * size : (i + 1) * size] = x
    # Display the grid
    scale = 20. / n_features
    plt.figure(figsize=(scale * n_features, scale))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2927ea4598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# terminamos el kernel y limpiamos la memoria

# %%
import os, signal
os.kill(os.getpid(), signal.SIGKILL)
